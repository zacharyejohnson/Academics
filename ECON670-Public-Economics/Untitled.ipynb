# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('unmarried_births_data.csv', index_col=0, infer_datetime_format=True)

# %%
data['Number of Births'] = data['Number of Births'].str.replace(',', '').astype(float)

# %%
data['Age Group'].unique()
# Out:
# array(['15-19 years', '20-24 years', '25-29 years', '30-34 years',
#        '35-39 years', '40+ years', 'Less than 15 years'], dtype=object)

# %%
fig, ax = plt.subplots(figsize = (12, 8))
data.plot(ax=ax)
# Out:
# <AxesSubplot:xlabel='Year'>
