# %% [markdown]
# # Data Homework: Chapter 3
#
# Name:<u> Zach Johnson

# %% [markdown]
# Download the following data:
#
# >Global Price of Brent Crude (U.S. Dollars per Pound): POILBREUSDQ
# >
# >Global Price of Bananas (U.S. Dollars per Pound): PBANSOPUSDQ
# >
# >Global Price of Orange (U.S. Dollars per Pound): PORANGUSDM
# >
# >CPI – Total All Items for the United States: CPIAUCSL

# %%
#plots.py
# the cat is brown 
# if you have not installed pandas-datareader, uncomment the command 
# in the next line. After intallation, you can remove the command
#!pip install pandas-datareader
# pandas_datareader is imported in datlib.FRED
import datetime
from datlib.FRED import *
# for each variable, enter the variable name followed by the variable code. 
# the first variable is completed for you
data_codes  = {"Brent Crude Oil Price":"POILBREUSDQ",
               "Bananas Price":"PBANSOPUSDQ",
               "Global Price of Oranges":"PORANGUSDM",
              "CPI": "CPIAUCSL"}
# Select start and end dates
# datetime.datetime(year, month, day)
start = datetime.datetime(1990, 1, 1)
end = datetime.datetime.today()

# %%
data = gather_data(data_codes = data_codes, 
                   start = start, 
                   end = end, 
                   freq = "Q")

# %%
keys = data.keys()
keys
# Out:
# Index(['Brent Crude Oil Price', 'Bananas Price', 'Global Price of Oranges',
#        'CPI', 'Real Brent Crude Oil Price', 'Real Bananas Price',
#        'Real Global Price of Oranges'],
#       dtype='object')

# %%
data[keys[:-1]]
# Out:
#             Brent Crude Oil Price  Bananas Price  Global Price of Oranges  \
# DATE
# 1990-03-31              19.850000     591.033333                 1.925521
# 1990-06-30              15.960000     535.900000                 1.924709
# 1990-09-30              26.496667     565.200000                 1.667892
# 1990-12-31              32.536667     471.266667                 1.149757
# 1991-03-31              20.750000     709.230000                 1.171534
# ...                           ...            ...                      ...
# 2020-09-30              42.718692    1252.543797                 1.185122
# 2020-12-31              44.516211    1139.648345                 1.193290
# 2021-03-31              60.567295    1231.528984                 1.140388
# 2021-06-30              68.626869    1229.281768                 1.151946
# 2021-09-30              73.001970    1218.399464                 1.355883
#
#                    CPI  Real Brent Crude Oil Price  Real Bananas Price
# DATE
# 1990-03-31  128.033333                    0.155038            4.616246
# 1990-06-30  129.300000                    0.123434            4.144625
# 1990-09-30  131.533333                    0.201445            4.297010
# 1990-12-31  133.766667                    0.243234            3.523050
# 1991-03-31  134.766667                    0.153970            5.262651
# ...                ...                         ...                 ...
# 2020-09-30  259.421333                    0.164669            4.828222
# 2020-12-31  260.983000                    0.170571            4.366753
# 2021-03-31  263.395000                    0.229949            4.675597
# 2021-06-30  268.788000                    0.255320            4.573425
# 2021-09-30  273.138333                    0.267271            4.460741
#
# [127 rows x 6 columns]

# %% [markdown]
# 1. Create line graphs reflecting the prices of each commodity over time.

# %%
# you will need to use functions from the datlib folder. 
# Reference the Data Homework Guide if you are unfamiliar with this
from datlib.plots import * 

plot_lines(data[keys[:-1]], linewidth=3)
# Out:
# C:\Users\jzach\Github Repositories\Macroeconomics-Growth-and-Monetary-Equilibrium\Data Homework Assignments\datlib\plots.py:21: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([round(x,2) for x in vals])

# %% [markdown]
# 2. The real price of commodity $i$ is calculated as $\frac{p_i}{P}$, the price of good $i$ divided by the price level. Calculate the real price of each good using $CPI$ as the price level, $P$.

# %%
#Hint: Use data[real_name] = data[name].div(data["CPI"])
# This could be easily accompished with a for loop. You are not required to use a for loop.

data["Real Brent Crude Oil Price"] = data["Brent Crude Oil Price"].div(data["CPI"])
data["Real Bananas Price"] = data["Bananas Price"].div(data["CPI"])
data["Real Global Price of Oranges"] = data["Global Price of Oranges"].div(data["CPI"])
data
# Out:
#             Brent Crude Oil Price  Bananas Price  Global Price of Oranges  \
# DATE
# 1990-03-31              19.850000     591.033333                 1.925521
# 1990-06-30              15.960000     535.900000                 1.924709
# 1990-09-30              26.496667     565.200000                 1.667892
# 1990-12-31              32.536667     471.266667                 1.149757
# 1991-03-31              20.750000     709.230000                 1.171534
# ...                           ...            ...                      ...
# 2020-09-30              42.718692    1252.543797                 1.185122
# 2020-12-31              44.516211    1139.648345                 1.193290
# 2021-03-31              60.567295    1231.528984                 1.140388
# 2021-06-30              68.626869    1229.281768                 1.151946
# 2021-09-30              73.001970    1218.399464                 1.355883
#
#                    CPI  Real Brent Crude Oil Price  Real Bananas Price  \
# DATE
# 1990-03-31  128.033333                    0.155038            4.616246
# 1990-06-30  129.300000                    0.123434            4.144625
# 1990-09-30  131.533333                    0.201445            4.297010
# 1990-12-31  133.766667                    0.243234            3.523050
# 1991-03-31  134.766667                    0.153970            5.262651
# ...                ...                         ...                 ...
# 2020-09-30  259.421333                    0.164669            4.828222
# 2020-12-31  260.983000                    0.170571            4.366753
# 2021-03-31  263.395000                    0.229949            4.675597
# 2021-06-30  268.788000                    0.255320            4.573425
# 2021-09-30  273.138333                    0.267271            4.460741
#
#             Real Global Price of Oranges
# DATE
# 1990-03-31                      0.015039
# 1990-06-30                      0.014886
# 1990-09-30                      0.012680
# 1990-12-31                      0.008595
# 1991-03-31                      0.008693
# ...                                  ...
# 2020-09-30                      0.004568
# 2020-12-31                      0.004572
# 2021-03-31                      0.004330
# 2021-06-30                      0.004286
# 2021-09-30                      0.004964
#
# [127 rows x 7 columns]

# %% [markdown]
# 3. Create a separate graph of the real price for each good $i$.

# %%
data[keys[4:]]
plt.rcParams.update({"font.size":32})
plot_lines(data[keys[4:]], linewidth=3, secondary_y= "Real Bananas Price")
# Out:
# C:\Users\jzach\Github Repositories\Macroeconomics-Growth-and-Monetary-Equilibrium\Data Homework Assignments\datlib\plots.py:21: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([round(x,2) for x in vals])

# %% [markdown]
# 4. Have goods tended to become more or less expensive in real terms? Why do you think this is?

# %% [markdown]
# Oil has become significantly more expensive due to various factors such as conflicts in the middle east, and crack downs on non-environmentally friendly methods of extraction.
#
# Bananas have also become slightly more expensive, perhaps due to massively increased demand from millenials intersted in making acai bowls with banana, coupled with a decrease in ecuadorian exports of the commodity
#
# Oranges, a less hip commodity, have become chape in real terms due to increased efficiency in production. LRAS went up. See grph from class for non-monetary goods.

# %% [markdown]
# 5. Calculate a dataframe that holds that annual percent change of each variable, and plot all of the variables on the same graph.
# (Hint: The dataframe has been created for you. It calculate the percent change of each variable over 4 quarters, or 1 year)

# %%
#Hint: pct_change_data = data.pct_change(num_periods).dropna()

# %%
pct_change_data = data.pct_change(4).dropna()

# %%
plot_lines(pct_change_data, linewidth = 3)
# Out:
# C:\Users\jzach\Github Repositories\Macroeconomics-Growth-and-Monetary-Equilibrium\Data Homework Assignments\datlib\plots.py:21: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([round(x,2) for x in vals])

# %% [markdown]
# 6. Is the price level more or less stable than the price of specific goods? Whatever your response, why do you think this is the case?

# %% [markdown]
# the price level is more stable than the price of specific goods, as we can see much less variation in their graphs.
# Perhaps this is because we print a constant rate of money and the fed tries to hit a specific inflation target each year.
