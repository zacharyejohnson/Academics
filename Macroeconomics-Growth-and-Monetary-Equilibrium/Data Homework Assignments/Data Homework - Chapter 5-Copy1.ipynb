# %% [markdown]
# # Data Homework: Chapter 5
#
# Name:<u> Enter your full name here

# %% [markdown]
# Directions: Download the following data in from [FRED] (https://fred.stlouisfed.org/graph/?g=pUAe) using pandas_datareader
#
# >GDP Deflator: GDPDEF
# >
# >Monetary Base: BOGMBASEW
#
# 1.	Calculate the real base money stock (M/P) using data for the GDP Deflator and the Monetary Base. Make sure to reindex the price level by dividing it by 100.
#
# $(1/1/100) --> 1 * 100$

# %%
import pandas_datareader.data as web
import datetime as dt
from datlib.FRED import *

start = dt.datetime(1975,1,1)
data_codes = {"GDP Deflator": "GDPDEF", "Monetary Base": "BOGMBASEW"}
data = gather_data(data_codes, start = start)
GDP_deflator = data["GDP Deflator"].div(100)
data["Real Monetary Base"] = data["Monetary Base"].div(GDP_deflator)

# %%
data
# Out:
#             GDP Deflator  Monetary Base  Real Monetary Base
# DATE
# 1975-12-31      29.82150   1.085907e+05        3.641356e+05
# 1976-12-31      31.46750   1.147075e+05        3.645269e+05
# 1977-12-31      33.41850   1.229158e+05        3.678078e+05
# 1978-12-31      35.76175   1.344767e+05        3.760350e+05
# 1979-12-31      38.74150   1.474940e+05        3.807131e+05
# 1980-12-31      42.24700   1.586598e+05        3.755528e+05
# 1981-12-31      46.24400   1.641010e+05        3.548589e+05
# 1982-12-31      49.10050   1.722985e+05        3.509099e+05
# 1983-12-31      51.01200   1.833834e+05        3.594907e+05
# 1984-12-31      52.85775   1.951790e+05        3.692534e+05
# 1985-12-31      54.53150   2.104711e+05        3.859624e+05
# 1986-12-31      55.63250   2.309560e+05        4.151459e+05
# 1987-12-31      57.00375   2.533728e+05        4.444845e+05
# 1988-12-31      59.01325   2.719907e+05        4.608976e+05
# 1989-12-31      61.33125   2.834332e+05        4.621350e+05
# 1990-12-31      63.63150   3.018995e+05        4.744497e+05
# 1991-12-31      65.77950   3.182647e+05        4.838357e+05
# 1992-12-31      67.27675   3.417977e+05        5.080472e+05
# 1993-12-31      68.87275   3.767648e+05        5.470449e+05
# 1994-12-31      70.34250   4.114779e+05        5.849635e+05
# 1995-12-31      71.81975   4.339212e+05        6.041808e+05
# 1996-12-31      73.13300   4.478925e+05        6.124355e+05
# 1997-12-31      74.39475   4.721412e+05        6.346431e+05
# 1998-12-31      75.23225   5.026265e+05        6.680998e+05
# 1999-12-31      76.29125   5.515447e+05        7.229461e+05
# 2000-12-31      78.02075   5.853426e+05        7.502396e+05
# 2001-12-31      79.78200   6.178603e+05        7.744357e+05
# 2002-12-31      81.02425   6.729469e+05        8.305500e+05
# 2003-12-31      82.61875   7.164234e+05        8.671439e+05
# 2004-12-31      84.83650   7.526400e+05        8.871653e+05
# 2005-12-31      87.49850   7.824317e+05        8.942230e+05
# 2006-12-31      90.20100   8.113185e+05        8.994562e+05
# 2007-12-31      92.63800   8.270978e+05        8.928278e+05
# 2008-12-31      94.42250   9.860173e+05        1.044261e+06
# 2009-12-31      95.02275   1.776310e+06        1.869353e+06
# 2010-12-31      96.16150   2.009185e+06        2.089386e+06
# 2011-12-31      98.16100   2.515361e+06        2.562485e+06
# 2012-12-31      99.99850   2.640353e+06        2.640392e+06
# 2013-12-31     101.74750   3.239690e+06        3.184049e+06
# 2014-12-31     103.64850   3.922705e+06        3.784623e+06
ories\Macroeconomics-Growth-and-Monetary-Equilibrium\Data Homework Assignments\datlib\plots.py in plot_lines(df, linewidth, figsize, secondary_y, legend, pp, save_fig)
#      12     fig, ax = plt.subplots(figsize = figsize)
#      13     # If no secondary_y (axis), plot all variables at once
# ---> 14     df.dropna().plot.line(linewidth = linewidth, ax = ax, secondary_y=secondary_y, legend = legend)
#      15     # Turn the text on the x-axis so that it reads vertically
#      16     ax.tick_params(axis='x', rotation=90)
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in line(self, x, y, **kwargs)
#    1021         as coordinates.
#    1022         """
# -> 1023         return self(kind="line", x=x, y=y, **kwargs)
#    1024
#    1025     @Appender(
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     953                     data.columns = label_name
#     954
# --> 955         return plot_backend.plot(data, kind=kind, **kwargs)
#     956
#     957     __call__.__doc__ = __doc__
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     278         self._compute_plot_data()
#     279         self._setup_subplots()
# --> 280         self._make_plot()
#     281         self._add_table()
#     282         self._make_legend()
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in _make_plot(self)
#    1147             kwds["label"] = label
#    1148
# -> 1149             newlines = plotf(
#    1150                 ax,
#    1151                 x,
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in _ts_plot(cls, ax, x, data, style, **kwds)
#    1196         ax._plot_data.append((data, cls._kind, kwds))
#    1197
# -> 1198         lines = cls._plot(ax, data.index, data.values, style=style, **kwds)
#    1199         # set date formatter, locators and rescale limits
#    1200         format_dateaxis(ax, ax.freq, data.index)
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in _plot(cls, ax, x, y, style, column_num, stacking_id, **kwds)
#    1176             cls._initialize_stacker(ax, stacking_id, len(y))
#    1177         y_values = cls._get_stacked_values(ax, stacking_id, y, kwds["label"])
# -> 1178         lines = MPLPlot._plot(ax, x, y_values, style=style, **kwds)
#    1179         cls._update_stacker(ax, stacking_id, y)
#    1180         return lines
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\converter.py in wrapper(*args, **kwargs)
#      64     def wrapper(*args, **kwargs):
#      65         with pandas_converters():
# ---> 66             return func(*args, **kwargs)
#      67
#      68     return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in _plot(cls, ax, x, y, style, is_errorbar, **kwds)
#     695             else:
#     696                 args = (x, y)  # type: ignore[assignment]
# --> 697             return ax.plot(*args, **kwds)
#     698
#     699     def _get_index_name(self) -> Optional[str]:
#
# ~\AppData\Roaming\Python\Python38\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1603         """
#    1604         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1605         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1606         for line in lines:
#    1607             self.add_line(line)
#
# ~\AppData\Roaming\Python\Python38\site-packages\matplotlib\axes\_base.py in __call__(self, data, *args, **kwargs)
#     313                 this += args[0],
#     314                 args = args[1:]
# --> 315             yield from self._plot_args(this, kwargs)
#     316
#     317     def get_next_color(self):
#
# ~\AppData\Roaming\Python\Python38\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     537             return list(result)
#     538         else:
# --> 539             return [l[0] for l in result]
#     540
#     541
#
# ~\AppData\Roaming\Python\Python38\site-packages\matplotlib\axes\_base.py in <listcomp>(.0)
#     537             return list(result)
#     538         else:
# --> 539             return [l[0] for l in result]
#     540
#     541
#
# ~\AppData\Roaming\Python\Python38\site-packages\matplotlib\axes\_base.py in <genexpr>(.0)
#     530             labels = [label] * n_datasets
#     531
# --> 532         result = (make_artist(x[:, j % ncx], y[:, j % ncy], kw,
#     533                               {**kwargs, 'label': label})
#     534                   for j, label in enumerate(labels))
#
# ~\AppData\Roaming\Python\Python38\site-packages\matplotlib\axes\_base.py in _makeline(self, x, y, kw, kwargs)
#     352         default_dict = self._getdefaults(set(), kw)
#     353         self._setdefaults(default_dict, kw)
# --> 354         seg = mlines.Line2D(x, y, **kw)
#     355         return seg, kw
#     356
#
# ~\AppData\Roaming\Python\Python38\site-packages\matplotlib\lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     367         self._us_dashOffset = 0
#     368
# --> 369         self.set_linewidth(linewidth)
#     370         self.set_linestyle(linestyle)
#     371         self.set_drawstyle(drawstyle)
#
# ~\AppData\Roaming\Python\Python38\site-packages\matplotlib\lines.py in set_linewidth(self, w)
#    1100             Line width, in points.
#    1101         """
# -> 1102         w = float(w)
#    1103
#    1104         if self._linewidth != w:
#
# TypeError: float() argument must be a string or a number, not 'DataFrame'

# %% [markdown]
# 5.	Graph the differenced logged values of both the Monetary Base and the Real Monetary Base on a single graph.

# %% [markdown]
# 6.	What does the slope of logged data approximate?

# %% [markdown]
# 7.	What does the difference of logged values represent?

# %% [markdown]
# 8.	What is the advantage of using logged values compared to using non-logged values for visualizing macroeconomic data?
