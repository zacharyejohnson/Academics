# %% [markdown]
# # Data Homework: Chapter 9
#
# Name:<u> Zach Johnson

# %% [markdown]
# Directions: Download the following data from [FRED](https://fred.stlouisfed.org/graph/?g=pUBb) using pandas_datareader.
#
# >Real Potential GDP: GDPPOT
# >
# >Potential GDP: NGDPPOT
# >
# >Real GDP: GDPC1
# >
# >Consumption: PCEC
# >
# >Investment: GPDI
# >
# >Government Spending: FGEXPND
# >
# >Federal Debt: GFDEBTN
# >
# >Nominal GDP: GDP

# %%
import datetime
from datlib.FRED import *
#Import monetary base
# {data_name1:data_code1,
#  data_name2:data_code2}
data_codes  = {"Real Potential GDP": "GDPPOT",
               "Potential GDP": "NGDPPOT",
               "Real GDP": "GDPC1",
               "Consumption": "PCEC",
               "Investment": "GPDI",
               "Federal Spending": "FGEXPND",
               "Federal Debt": "GFDEBTN",
               "Nominal GDP": "GDP",
               "GDP Deflator": "GDPDEF",
               "10 Year U.S. Treasury Rate":"DGS10"}
# Select start and end dates
start = datetime.datetime(1975, 1, 1)
end = datetime.datetime.today()
data = gather_data(data_codes = data_codes, 
                   start = start, 
                   end = end, 
                   freq = "Q")
data
# Out:
#             Real Potential GDP  Potential GDP   Real GDP  Consumption  \
# DATE
# 1975-03-31         5821.185285    1695.616153   5551.713      985.190
# 1975-06-30         5866.888923    1734.405994   5591.382     1013.582
# 1975-09-30         5912.175162    1778.624959   5687.087     1047.192
# 1975-12-31         5957.519332    1822.214854   5763.665     1076.223
# 1976-03-31         6002.790250    1855.519085   5893.276     1109.908
# ...                        ...            ...        ...          ...
# 2021-03-31        19602.540000   22644.980000  19055.655    15005.444
# 2021-06-30        19697.360000   22983.260000  19368.310    15681.699
# 2021-09-30        19795.820000   23233.130000  19478.893    15964.938
# 2021-12-31        19898.250000   23461.340000  19806.290    16314.201
# 2022-03-31        20003.730000   23698.030000        NaN          NaN
#
#             Investment  Federal Spending  Federal Debt  Nominal GDP  \
# DATE
# 1975-03-31     244.306           354.024      509659.0     1616.116
# 1975-06-30     243.281           377.665      533188.0     1651.853
# 1975-09-30     265.192           379.106      553647.0     1709.820
# 1975-12-31     276.236           388.241      576649.0     1761.831
# 1976-03-31     304.638           393.991      600490.0     1820.487
# ...                ...               ...           ...          ...
# 2021-03-31    3927.984          8071.420    28132570.0    22038.226
# 2021-06-30    3925.069          7490.479    28529436.0    22740.959
# 2021-09-30    4099.571          6560.351    28428919.0    23202.344
# 2021-12-31    4527.181          5963.497    29617215.0    24002.815
# 2022-03-31         NaN               NaN           NaN          NaN
#
#             GDP Deflator  10 Year U.S. Treasury Rate
# DATE
# 1975-03-31        29.110                    7.544167
# 1975-06-30        29.543                    8.051875
# 1975-09-30        30.065                    8.291562
# 1975-12-31        30.568                    8.063279
# 1976-03-31        30.891                    7.754032
# ...                  ...                         ...
# 2021-03-31       115.652                    1.335902
# 2021-06-30       117.413                    1.590781
# 2021-09-30       119.115                    1.324844
# 2021-12-31       121.188                    1.533387
# 2022-03-31           NaN                    1.938333
#
# [189 rows x 10 columns]

# %%
data["Federal Debt"] = data["Federal Debt"].div(1000)
data["Federal Debt / GDP"] = data["Federal Debt"].div(data["Nominal GDP"])
data["Inflation"] = data["GDP Deflator"].pct_change(4)*100
data["Real 10 Year U.S. Treasury Rate"] = data["10 Year U.S. Treasury Rate"].sub(data["Inflation"])
data
# Out:
#             Real Potential GDP  Potential GDP   Real GDP  Consumption  \
# DATE
# 1975-03-31         5821.185285    1695.616153   5551.713      985.190
# 1975-06-30         5866.888923    1734.405994   5591.382     1013.582
# 1975-09-30         5912.175162    1778.624959   5687.087     1047.192
# 1975-12-31         5957.519332    1822.214854   5763.665     1076.223
# 1976-03-31         6002.790250    1855.519085   5893.276     1109.908
# ...                        ...            ...        ...          ...
# 2021-03-31        19602.540000   22644.980000  19055.655    15005.444
# 2021-06-30        19697.360000   22983.260000  19368.310    15681.699
# 2021-09-30        19795.820000   23233.130000  19478.893    15964.938
# 2021-12-31        19898.250000   23461.340000  19806.290    16314.201
# 2022-03-31        20003.730000   23698.030000        NaN          NaN
#
#             Investment  Federal Spending  Federal Debt  Nominal GDP  \
# DATE
# 1975-03-31     244.306           354.024       509.659     1616.116
# 1975-06-30     243.281           377.665       533.188     1651.853
# 1975-09-30     265.192           379.106       553.647     1709.820
# 1975-12-31     276.236           388.241       576.649     1761.831
# 1976-03-31     304.638           393.991       600.490     1820.487
# ...                ...               ...           ...          ...
# 2021-03-31    3927.984          8071.420     28132.570    22038.226
# 2021-06-30    3925.069          7490.479     28529.436    22740.959
# 2021-09-30    4099.571          6560.351     28428.919    23202.344
# 2021-12-31    4527.181          5963.497     29617.215    24002.815
# 2022-03-31         NaN               NaN           NaN          NaN
#
#             GDP Deflator  10 Year U.S. Treasury Rate  Federal Debt / GDP  \
# DATE
# 1975-03-31        29.110                    7.544167            0.315360
# 1975-06-30        29.543                    8.051875            0.322782
# 1975-09-30        30.065                    8.291562            0.323804
# 1975-12-31        30.568                    8.063279            0.327301
# 1976-03-31        30.891                    7.754032            0.329851
# ...                  ...                         ...                 ...
# 2021-03-31       115.652                    1.335902            1.276535
# 2021-06-30       117.413                    1.590781            1.254540
# 2021-09-30       119.115                    1.324844            1.225261
# 2021-12-31       121.188                    1.533387            1.233906
# 2022-03-31           NaN                    1.938333                 NaN
#
#             Inflation  Real 10 Year U.S. Treasury Rate
# DATE
# 1975-03-31        NaN                              NaN
# 1975-06-30        NaN                              NaN
# 1975-09-30        NaN                              NaN
# 1975-12-31        NaN                              NaN
# 1976-03-31   6.118172                         1.635860
# ...               ...                              ...
# 2021-03-31   2.034478                        -0.698577
# 2021-06-30   4.035123                        -2.444342
# 2021-09-30   4.589597                        -3.264753
# 2021-12-31   5.897465                        -4.364078
# 2022-03-31   4.786774                        -2.848441
#
# [189 rows x 13 columns]

# %% [markdown]
# 1.	Calculate the difference between Potential GDP and observed GDP. Assume that Potential GDP represents Long-run Aggregate Supply (LRAS). Plot these values. Indicate whether positive (negative) values represent an excess supply of goods or excess demand for goods.

# %%
from datlib.plots import *
plt.rcParams.update({'font.size': 32})
plt.rcParams['axes.ymargin'] = 0
plt.rcParams['axes.xmargin'] = 0
# a negative excess supply of goods is an excess demand for goods
# Potential GDP approximates LRAS
# Nominal (observed) GDP is our estimate of aggregate demand
data["Excess Supply"] = data["Potential GDP"].sub(data["Nominal GDP"])
data_to_plot = data[["Excess Supply", "Potential GDP", "Nominal GDP"]]
plot_lines(data_to_plot, secondary_y = "Excess Supply")
# Out:
# C:\Users\jzach\Github Repositories\Macroeconomics-Growth-and-Monetary-Equilibrium\Data Homework Assignments\datlib\plots.py:21: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([round(x,2) for x in vals])

# %% [markdown]
# ## Next, as example, I will calculate the excess supply using logged values.

# %%
# Use a for loop to create logged values
# data_codes.keys() will call the variable names 
# we defined at the beginning of the assignment
# you can perform a similar operation to create 
# log-differenced values
for name in data_codes.keys():
    data["Log "+name] = np.log(data[name])

# %%
data["Log Excess Supply"] = data["Log Potential GDP"].sub(data["Log Nominal GDP"])
data_to_plot = data[["Log Excess Supply", "Log Potential GDP", "Log Nominal GDP"]]
plot_lines(data_to_plot, secondary_y = "Log Excess Supply")
# Out:
# C:\Users\jzach\Github Repositories\Macroeconomics-Growth-and-Monetary-Equilibrium\Data Homework Assignments\datlib\plots.py:21: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([round(x,2) for x in vals])

# %% [markdown]
# 2.	Calculate Real Excess Supply of or Demand for Goods using calculation similar to those used in questions 1. Plot these values. Indicate whether positive (negative) values represent an excess supply of goods or excess demand for goods.

# %%
data["Real Excess Supply"] = data["Real Potential GDP"].sub(data["Real GDP"])
data
# Out:
#             Real Potential GDP  Potential GDP   Real GDP  Consumption  \
# DATE
# 1975-03-31         5821.185285    1695.616153   5551.713      985.190
# 1975-06-30         5866.888923    1734.405994   5591.382     1013.582
# 1975-09-30         5912.175162    1778.624959   5687.087     1047.192
# 1975-12-31         5957.519332    1822.214854   5763.665     1076.223
# 1976-03-31         6002.790250    1855.519085   5893.276     1109.908
# ...                        ...            ...        ...          ...
# 2021-03-31        19602.540000   22644.980000  19055.655    15005.444
# 2021-06-30        19697.360000   22983.260000  19368.310    15681.699
# 2021-09-30        19795.820000   23233.130000  19478.893    15964.938
# 2021-12-31        19898.250000   23461.340000  19806.290    16314.201
# 2022-03-31        20003.730000   23698.030000        NaN          NaN
#
#             Investment  Federal Spending  Federal Debt  Nominal GDP  \
# DATE
# 1975-03-31     244.306           354.024       509.659     1616.116
# 1975-06-30     243.281           377.665       533.188     1651.853
# 1975-09-30     265.192           379.106       553.647     1709.820
# 1975-12-31     276.236           388.241       576.649     1761.831
# 1976-03-31     304.638           393.991       600.490     1820.487
# ...                ...               ...           ...          ...
# 2021-03-31    3927.984          8071.420     28132.570    22038.226
# 2021-06-30    3925.069          7490.479     28529.436    22740.959
# 2021-09-30    4099.571          6560.351     28428.919    23202.344
# 2021-12-31    4527.181          5963.497     29617.215    24002.815
# 2022-03-31         NaN               NaN           NaN          NaN
#
#             GDP Deflator  10 Year U.S. Treasury Rate  ...  \
# DATE                                                  ...
# 1975-03-31        29.110                    7.544167  ...
# 1975-06-30        29.543                    8.051875  ...
# 1975-09-30        30.065                    8.291562  ...
# 1975-12-31        30.568                    8.063279  ...
# 1976-03-31        30.891                    7.754032  ...
# ...                  ...                         ...  ...
# 2021-03-31       115.652                    1.335902  ...
# 2021-06-30       117.413                    1.590781  ...
# 2021-09-30       119.115                    1.324844  ...
# 2021-12-31       121.188                    1.533387  ...
# 2022-03-31           NaN                    1.938333  ...
#
#             Log 10 Year U.S. Treasury Rate  Log Excess Supply  \
# DATE
# 1975-03-31                        2.020775           0.048020
# 1975-06-30                        2.085905           0.048767
# 1975-09-30                        2.115238           0.039452
# 1975-12-31                        2.087320           0.033699
# 1976-03-31                        2.048213           0.019060
# ...                                    ...                ...
# 2021-03-31                        0.289606           0.027160
# 2021-06-30                        0.464225           0.010598
# 2021-09-30                        0.281295           0.001326
# 2021-12-31                        0.427479          -0.022817
# 2022-03-31                        0.661828                NaN
#
#             Real Excess Supply  Real Potential GDPLogged Difference  \
# DATE
# 1975-03-31          269.472285                                  NaN
# 1975-06-30          275.506923                             0.007851
# 1975-09-30          225.088162                             0.007719
# 1975-12-31          193.854332                             0.007670
# 1976-03-31          109.514250                             0.007599
# ...                        ...                                  ...
# 2021-03-31          546.885000                             0.004639
# 2021-06-30          329.050000                             0.004837
# 2021-09-30          316.927000                             0.004999
# 2021-12-31           91.960000                             0.005174
# 2022-03-31                 NaN                             0.005301
#
#             Potential GDPLogged Difference  Real GDPLogged Difference  \
# DATE
# 1975-03-31                             NaN                        NaN
# 1975-06-30                        0.022877                   0.007145
# 1975-09-30                        0.025495                   0.017117
# 1975-12-31                        0.024508                   0.013465
# 1976-03-31                        0.018277                   0.022488
# ...                                    ...                        ...
# 2021-03-31                        0.014768                   0.015339
# 2021-06-30                        0.014938                   0.016407
# 2021-09-30                        0.010872                   0.005709
# 2021-12-31                        0.009823                   0.016808
# 2022-03-31                        0.010089                   0.000000
#
#             Nominal GDPLogged Difference  Logged Difference Excess Supply  \
# DATE
# 1975-03-31                           NaN                              NaN
# 1975-06-30                      0.022113                         0.000764
# 1975-09-30                      0.035092                        -0.009597
# 1975-12-31                      0.030419                        -0.005911
# 1976-03-31                      0.033293                        -0.015016
# ...                                  ...                              ...
# 2021-03-31                      0.026103                        -0.011335
# 2021-06-30                      0.031887                        -0.016949
# 2021-09-30                      0.020289                        -0.009417
# 2021-12-31                      0.034500                        -0.024677
# 2022-03-31                      0.000000                         0.010089
#
#             Logged Difference Real Excess Supply  \
# DATE
# 1975-03-31                                   NaN
# 1975-06-30                             -0.067171
# 1975-09-30                             -0.109270
# 1975-12-31                             -0.092072
# 1976-03-31                             -0.100423
# ...                                          ...
# 2021-03-31                             -0.017983
# 2021-06-30                             -0.022383
# 2021-09-30                             -0.012073
# 2021-12-31                             -0.023359
# 2022-03-31                                   NaN
#
#             Government Spending Percent of GDP
# DATE
# 1975-03-31                            0.219059
# 1975-06-30                            0.228631
# 1975-09-30                            0.221723
# 1975-12-31                            0.220362
# 1976-03-31                            0.216421
# ...                                        ...
# 2021-03-31                            0.366246
# 2021-06-30                            0.329383
# 2021-09-30                            0.282745
# 2021-12-31                            0.248450
# 2022-03-31                                 NaN
#
# [189 rows x 33 columns]

# %%
from datlib.plots import *

# %%
data_to_plot = data[["Real Excess Supply", "Real Potential GDP", "Real GDP"]]
plot_lines(data_to_plot, secondary_y = "Real Excess Supply")
# Out:
# C:\Users\jzach\Github Repositories\Macroeconomics-Growth-and-Monetary-Equilibrium\Data Homework Assignments\datlib\plots.py:21: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([round(x,2) for x in vals])

# %% [markdown]
# 3.	Calculate the logged-difference for each variable Real Potential GDP, Potential GDP, Real GDP, and Nominal GDP.

# %%
vars = ["Real Potential GDP", "Potential GDP", "Real GDP", "Nominal GDP"]
for var in vars: 
    data[var + "Logged Difference"] = np.log(data[var] / data[var].shift(1)) # this is the exact same thing as logged difference
data
# Out:
#             Real Potential GDP  Potential GDP   Real GDP  Consumption  \
# DATE
# 1975-03-31         5821.185285    1695.616153   5551.713      985.190
# 1975-06-30         5866.888923    1734.405994   5591.382     1013.582
# 1975-09-30         5912.175162    1778.624959   5687.087     1047.192
# 1975-12-31         5957.519332    1822.214854   5763.665     1076.223
# 1976-03-31         6002.790250    1855.519085   5893.276     1109.908
# ...                        ...            ...        ...          ...
# 2021-03-31        19602.540000   22644.980000  19055.655    15005.444
# 2021-06-30        19697.360000   22983.260000  19368.310    15681.699
# 2021-09-30        19795.820000   23233.130000  19478.893    15964.938
# 2021-12-31        19898.250000   23461.340000  19806.290    16314.201
# 2022-03-31        20003.730000   23698.030000        NaN          NaN
#
#             Investment  Federal Spending  Federal Debt  Nominal GDP  \
# DATE
# 1975-03-31     244.306           354.024       509.659     1616.116
# 1975-06-30     243.281           377.665       533.188     1651.853
# 1975-09-30     265.192           379.106       553.647     1709.820
# 1975-12-31     276.236           388.241       576.649     1761.831
# 1976-03-31     304.638           393.991       600.490     1820.487
# ...                ...               ...           ...          ...
# 2021-03-31    3927.984          8071.420     28132.570    22038.226
# 2021-06-30    3925.069          7490.479     28529.436    22740.959
# 2021-09-30    4099.571          6560.351     28428.919    23202.344
# 2021-12-31    4527.181          5963.497     29617.215    24002.815
# 2022-03-31         NaN               NaN           NaN          NaN
#
#             GDP Deflator  10 Year U.S. Treasury Rate  ...  \
# DATE                                                  ...
# 1975-03-31        29.110                    7.544167  ...
# 1975-06-30        29.543                    8.051875  ...
# 1975-09-30        30.065                    8.291562  ...
# 1975-12-31        30.568                    8.063279  ...
# 1976-03-31        30.891                    7.754032  ...
# ...                  ...                         ...  ...
# 2021-03-31       115.652                    1.335902  ...
# 2021-06-30       117.413                    1.590781  ...
# 2021-09-30       119.115                    1.324844  ...
# 2021-12-31       121.188                    1.533387  ...
# 2022-03-31           NaN                    1.938333  ...
#
#             Log 10 Year U.S. Treasury Rate  Log Excess Supply  \
# DATE
# 1975-03-31                        2.020775           0.048020
# 1975-06-30                        2.085905           0.048767
# 1975-09-30                        2.115238           0.039452
# 1975-12-31                        2.087320           0.033699
# 1976-03-31                        2.048213           0.019060
# ...                                    ...                ...
# 2021-03-31                        0.289606           0.027160
# 2021-06-30                        0.464225           0.010598
# 2021-09-30                        0.281295           0.001326
# 2021-12-31                        0.427479          -0.022817
# 2022-03-31                        0.661828                NaN
#
#             Real Excess Supply  Real Potential GDPLogged Difference  \
# DATE
# 1975-03-31          269.472285                                  NaN
# 1975-06-30          275.506923                             0.007821
# 1975-09-30          225.088162                             0.007689
# 1975-12-31          193.854332                             0.007640
# 1976-03-31          109.514250                             0.007570
# ...                        ...                                  ...
# 2021-03-31          546.885000                             0.004628
# 2021-06-30          329.050000                             0.004825
# 2021-09-30          316.927000                             0.004986
# 2021-12-31           91.960000                             0.005161
# 2022-03-31                 NaN                             0.005287
#
#             Potential GDPLogged Difference  Real GDPLogged Difference  \
# DATE
# 1975-03-31                             NaN                        NaN
# 1975-06-30                        0.022619                   0.007120
# 1975-09-30                        0.025176                   0.016972
# 1975-12-31                        0.024212                   0.013375
# 1976-03-31                        0.018112                   0.022238
# ...                                    ...                        ...
# 2021-03-31                        0.014660                   0.015222
# 2021-06-30                        0.014828                   0.016274
# 2021-09-30                        0.010813                   0.005693
# 2021-12-31                        0.009775                   0.016668
# 2022-03-31                        0.010038                        NaN
#
#             Nominal GDPLogged Difference  Logged Difference Excess Supply  \
# DATE
# 1975-03-31                           NaN                              NaN
# 1975-06-30                      0.021872                         0.000764
# 1975-09-30                      0.034490                        -0.009597
# 1975-12-31                      0.029966                        -0.005911
# 1976-03-31                      0.032750                        -0.015016
# ...                                  ...                              ...
# 2021-03-31                      0.025768                        -0.011335
# 2021-06-30                      0.031389                        -0.016949
# 2021-09-30                      0.020086                        -0.009417
# 2021-12-31                      0.033918                        -0.024677
# 2022-03-31                           NaN                         0.010089
#
#             Logged Difference Real Excess Supply  \
# DATE
# 1975-03-31                                   NaN
# 1975-06-30                             -0.067171
# 1975-09-30                             -0.109270
# 1975-12-31                             -0.092072
# 1976-03-31                             -0.100423
# ...                                          ...
# 2021-03-31                             -0.017983
# 2021-06-30                             -0.022383
# 2021-09-30                             -0.012073
# 2021-12-31                             -0.023359
# 2022-03-31                                   NaN
#
#             Government Spending Percent of GDP
# DATE
# 1975-03-31                            0.219059
# 1975-06-30                            0.228631
# 1975-09-30                            0.221723
# 1975-12-31                            0.220362
# 1976-03-31                            0.216421
# ...                                        ...
# 2021-03-31                            0.366246
# 2021-06-30                            0.329383
# 2021-09-30                            0.282745
# 2021-12-31                            0.248450
# 2022-03-31                                 NaN
#
# [189 rows x 33 columns]

# %% [markdown]
# 4.	Using rates instead of observed values, calculate Excess Demand of or Excess Supply of Goods.

# %%
data["Logged Difference Excess Supply"] = data["Potential GDPLogged Difference"] - data["Nominal GDPLogged Difference"]
plot_lines(data["Logged Difference Excess Supply"])
# Out:
# C:\Users\jzach\Github Repositories\Macroeconomics-Growth-and-Monetary-Equilibrium\Data Homework Assignments\datlib\plots.py:21: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([round(x,2) for x in vals])

# %% [markdown]
# 5.	Using rates instead of observed values, calculate Real Excess Demand of or Real Excess Supply of Goods.

# %%
data["Logged Difference Real Excess Supply"] = data["Real Potential GDPLogged Difference"].sub(data["Nominal GDPLogged Difference"].mul((gdp_def / data["GDP Deflator"])))
plot_vars = ["Logged Difference Excess Supply", "Logged Difference Real Excess Supply"]
plot_lines(data[plot_vars])
# Out:
# C:\Users\jzach\Github Repositories\Macroeconomics-Growth-and-Monetary-Equilibrium\Data Homework Assignments\datlib\plots.py:21: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([round(x,2) for x in vals])

# %% [markdown]
# 6.	Calculate government spending as a percent of Nominal GDP and plot this new variable. How has this variable changed over the last several decades?

# %%
data["Government Spending Percent of GDP"] = data["Federal Spending"].div(data["Nominal GDP"]) * 100
plot_lines(data["Government Spending Percent of GDP"])
# Out:
# C:\Users\jzach\Github Repositories\Macroeconomics-Growth-and-Monetary-Equilibrium\Data Homework Assignments\datlib\plots.py:21: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([round(x,2) for x in vals])

# %% [markdown]
# Government spending as a percent of GDP remained relatively stable from 1970 until 2020, hovering around 20-25 percent. We can see it dipped in the late 20th century when Clinton tried to balance the budget, and jumped a bit after the 2008 financial crisis. The COVID-19 pandemic shuttled in massive government spending, causing the percentage to jump up to almost 50. This has recently died down a bit, but is not yet at pre-pandemic levels. We will wait to see if spending does die down.
